# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

def make_data():
    M, N = 1000, 100
    means = np.random.uniform(-10, 10, N)
    cov_sqrt = np.random.uniform(-1, 1, (N, N))
    cov = cov_sqrt @ cov_sqrt.T
    X = np.random.multivariate_normal(means, cov, M)
    a = np.zeros(N)
    a[np.random.randint(0, N, 3)] = 1 *\
        np.array([-1, 1])[np.random.randint(0, 2, 3)] *\
        np.random.uniform(2, 5, 3)
    Y = X @ a + np.random.normal(0, 1, M)
    return X, Y, a

# %%
X, Y, a = make_data()

# %% [markdown]
# Suppose you measure some quantity $Y$ that you are intereted in predicting, and you also measure a bunch of different variables $X$ that $Y$ might depend on. You know that $Y$ depends on a few of the features in $X$, but most features in $X$ are irrelevant.
# * How do you define "relevant"?
# * How do you find the relevant features? Illustrate your method with code.
# * How will your method scale to more features, or more data points?

# %%
a0 = np.linalg.lstsq(X, Y, rcond=None)[0]

# %%
plt.plot(np.abs(a0))
plt.plot(1e-3 + np.abs(a))
