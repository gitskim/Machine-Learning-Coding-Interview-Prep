# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
plt.style.use("bmh")

# %%
N = 1000
w0 = np.array([1, 2])
X = np.empty((N, 2))
X[:, 1] = 1 # for b
X[:, 0] = np.random.normal(0, 1, N)
y0 = X @ w0 #w0 does not have to be transposed
y = y0 + np.random.normal(0, 0.1, N)

# %%
w0
# Out:
# array([1, 2])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(X[:, 0], y0, ".", label="no noise") # no noise
ax.plot(X[:, 0], y, ".", alpha=0.25, label="noise") # noise
ax.legend(loc=0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def mse(y_pred, y_true):
    # TODO

# %% [markdown]
# # Solve for W with pseudo inverse

# %% [markdown]
# $MSE = 1/N\sum_{i=1}^{N}(y_{pred} - y_{i_{true}})^2$

# %% [markdown]
# $= 1/N\sum_{i=1}^{N}(xw - y_{i_{true}})^2$

# %%
def mse_psudo_inverse():
    # TODO

# %% [markdown]
# # Solve for W with gradient descent

# %%
def gradient_descent():
    # TODO

# %%
def mse_grad():
    # TODO
