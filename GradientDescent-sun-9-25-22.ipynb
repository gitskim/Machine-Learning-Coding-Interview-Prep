# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
plt.style.use("bmh")

# %%
def f(w):
    # TODO

def gradf(w):
    # TODO

def gradient_descent(f, gradf, eta, w):
    # TODO

# %%
def loss(w):
    return 1 + w[0]**2 + (w[1]**2)/2
    
def gradloss(w):
    return np.array([2*w[0], 1*w[1]])

# %%
gradient_descent2(loss, gradloss, eta, np.array([1, 1]))
# Out:
# array([0.      , 0.015625])

# %%
N = 1000
w0 = np.array([1, 2])
X = np.empty((N, 2))
X[:, 1] = 1 # for b
X[:, 0] = np.random.normal(0, 1, N)
y0 = X @ w0 #w0 does not have to be transposed
y = y0 + np.random.normal(0, 0.1, N)

# %%
w0
# Out:
# array([1, 2])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(X[:, 0], y0, ".", label="no noise") # no noise
ax.plot(X[:, 0], y, ".", alpha=0.25, label="noise") # noise
ax.legend(loc=0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def mse(x, w, y):
    print((x[:3] @ w - y[:3])**2)
    return np.mean((x @ w - y)**2)

w_from_math = np.linalg.inv((X.T @ X)) @ X.T @ y
mse(X, w_from_math, y)
# Out:
# [0.02334993 0.00201948 0.00094511]
# 0.010576721582094321

# %%
w_from_math
# Out:
# array([0.99842049, 1.99877828])

# %%
def mse_grad(x, w, y):
    return np.array([
        np.mean(2 * (X@w - y) * X[:, 0]),
        np.mean(2 * (X@w - y) * X[:, 1])
    ])

# %%
mse_grad(X, 13*w0, y0)
# Out:
# array([24.61804662, 48.05193047])

# %%
def mse_grad_2(x, w, y):
    return 2 * x.T @ (x @ w - y) / N

mse_grad_2(X, 13*w0, y0)
# Out:
# array([24.61804662, 48.05193047])

# %%
gradient_descent2(lambda w : mse(X, w, y),
                  lambda w : mse_grad_2(X, w, y),
                  0.2, np.zeros(2))
# Out:
# [0.88931693 1.85592418 2.44738267]
# [0.88931693 1.85592418 2.44738267]
# [0.26330977 0.64745894 0.86423773]
# [0.26330977 0.64745894 0.86423773]
# [0.0633786  0.21893766 0.29968915]
# [0.0633786  0.21893766 0.29968915]
# [0.00862679 0.07001307 0.10069189]
# [0.00862679 0.07001307 0.10069189]
# [1.33068097e-05 2.01263964e-02 3.19614277e-02]
# [1.33068097e-05 2.01263964e-02 3.19614277e-02]
# [0.00387859 0.00459492 0.00909611]
# [0.00387859 0.00459492 0.00909611]
# [0.00958021 0.00053246 0.00203998]
# [0.00958021 0.00053246 0.00203998]
# [1.42774651e-02 1.52569747e-05 2.23327782e-04]
# [1.42774651e-02 1.52569747e-05 2.23327782e-04]
# [1.75832607e-02 4.07488466e-04 1.05418843e-05]
# [1.75832607e-02 4.07488466e-04 1.05418843e-05]
# [0.01975637 0.00090052 0.00020152]
# array([0.98982699, 1.97875715])

# %%
def myfun(a, b, c):
    print(a, b, c)
    return

# %%
myfun(1, 3, 5)
# Out:
# 1 3 5

# %%
g = lambda x : myfun(8, x, 9)

# %%
g(-123)
# Out:
# 8 -123 9
